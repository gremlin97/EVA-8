# %% [markdown]
# <a href="https://colab.research.google.com/github/gremlin97/EVA-8/blob/main/S12/S12_Yolov3_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Yolov3 Inference

# %%
# !cp /content/drive/MyDrive/Yolo/yolo_object_detection.zip /content
# !cp /content/drive/MyDrive/Yolo/yolov3.weights /content
# !cp /content/drive/MyDrive/Yolo/detect.jpg /content

# %%
# !unzip yolo_object_detection.zip
# Out:
# Archive:  yolo_object_detection.zip
#   inflating: room_ser.jpg
#   inflating: yolo_object_detection.py
#   inflating: coco.names
#   inflating: yolov3.cfg

# %%
import cv2
import numpy as np

# %%
# !python yolo_object_detection.py
# Out:
# [5 2 8]

# %% [markdown]
# ## Yolo Output:
# ![output.jpg](data:image/jpeg;base64,...)
